# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout, BatchNormalization
from tensorflow.keras.utils import to_categorical

# %%
# 1. 데이터 로드 및 전처리
df = pd.read_csv('C:/dataset/abalone.csv')

# %%
df
# Out:
#         id Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 0        0   M   0.455     0.365   0.095        0.5140          0.2245
# 1        1   M   0.350     0.265   0.090        0.2255          0.0995
# 2        2   F   0.530     0.420   0.135        0.6770          0.2565
# 3        3   M   0.440     0.365   0.125        0.5160          0.2155
# 4        4   I   0.330     0.255   0.080        0.2050          0.0895
# ...    ...  ..     ...       ...     ...           ...             ...
# 4172  4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173  4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174  4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175  4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176  4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera_weight  Shell_weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# 3             0.1140        0.1550     10
# 4             0.0395        0.0550      7
# ...              ...           ...    ...
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12
#
# [4177 rows x 10 columns]

# %%
# Rings 카테고리화
def categorize_rings(rings):
    if rings <= 8:
        return 0    # 어린 전복
    elif rings <= 12:
        return 1    # 중간 전복
    else:
        return 2    # 성숙 전복

# %%
df['Rings_category'] = df['Rings'].apply(categorize_rings)

# %%
# Sex 원-핫 인코딩
df = pd.get_dummies(df, columns=['Sex'])

# %%
# 특성과 타겟 분리
X = df.drop(['Rings', 'Rings_category', 'id'], axis=1)
y = df['Rings_category']

# %%
# 스케일링
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# LSTM 입력을 위한 reshape
X_reshaped = X_scaled.reshape(X_scaled.shape[0], 1, X_scaled.shape[1])

# %%
# 타겟 원-핫 인코딩
y = to_categorical(y)

# %%
# 데이터 분할
X_train, X_test, y_train, y_test = train_test_split(
    X_reshaped, y, test_size=0.2, random_state=42, stratify=y
)

# %%
# 2. LSTM 모델 구성
model = Sequential([
    # LSTM 레이어
    LSTM(128, input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=True),
    BatchNormalization(),
    Dropout(0.3),
    
    LSTM(64),
    BatchNormalization(),
    Dropout(0.2),
    
    # Dense 레이어
    Dense(32, activation='relu'),
    BatchNormalization(),
    Dense(16, activation='relu'),
    Dense(3, activation='softmax')  # 3개 클래스 분류
])
# Out:
# C:\Users\김경환\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# 3. 모델 컴파일
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
# 4. 모델 학습
history = model.fit(
    X_train, y_train,
    epochs=100,
    batch_size=32,
    validation_split=0.2,
    verbose=1
)
# Out:
# Epoch 1/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.4848 - loss: 1.0889 - val_accuracy: 0.4753 - val_loss: 0.9996
# Epoch 2/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7067 - loss: 0.7075 - val_accuracy: 0.4753 - val_loss: 0.9689
# Epoch 3/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6939 - loss: 0.6904 - val_accuracy: 0.5949 - val_loss: 0.9040
# Epoch 4/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6913 - loss: 0.7001 - val_accuracy: 0.6248 - val_loss: 0.8512
# Epoch 5/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7100 - loss: 0.6841 - val_accuracy: 0.6517 - val_loss: 0.7619
# Epoch 6/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7094 - loss: 0.6725 - val_accuracy: 0.6771 - val_loss: 0.7065
# Epoch 7/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7029 - loss: 0.6600 - val_accuracy: 0.6801 - val_loss: 0.6933
# Epoch 8/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7104 - loss: 0.6479 - val_accuracy: 0.6831 - val_loss: 0.7004
# Epoch 9/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7151 - loss: 0.6586 - val_accuracy: 0.6891 - val_loss: 0.6710
# Epoch 10/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7357 - loss: 0.6172 - val_accuracy: 0.6921 - val_loss: 0.6614
# Epoch 11/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7283 - loss: 0.6599 - val_accuracy: 0.7010 - val_loss: 0.6759
# Epoch 12/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7231 - loss: 0.6253 - val_accuracy: 0.6996 - val_loss: 0.6719
# Epoch 13/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7382 - loss: 0.6192 - val_accuracy: 0.6996 - val_loss: 0.6565
# Epoch 14/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7162 - loss: 0.6234 - val_accuracy: 0.7130 - val_loss: 0.6642
# Epoch 15/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7146 - loss: 0.6329 - val_accuracy: 0.7025 - val_loss: 0.6877
# Epoch 16/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7281 - loss: 0.6436 - val_accuracy: 0.7040 - val_loss: 0.6649
# Epoch 17/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7122 - loss: 0.6398 - val_accuracy: 0.6861 - val_loss: 0.6933
# Epoch 18/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7152 - loss: 0.6322 - val_accuracy: 0.6951 - val_loss: 0.6825
# Epoch 19/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7413 - loss: 0.6136 - val_accuracy: 0.7010 - val_loss: 0.6652
# Epoch 20/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7221 - loss: 0.6239 - val_accuracy: 0.7025 - val_loss: 0.6743
# Epoch 21/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7303 - loss: 0.6186 - val_accuracy: 0.7025 - val_loss: 0.6706
# Epoch 22/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7191 - loss: 0.6544 - val_accuracy: 0.7070 - val_loss: 0.6831
# Epoch 23/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7322 - loss: 0.6110 - val_accuracy: 0.6996 - val_loss: 0.6693
# Epoch 24/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7262 - loss: 0.6148 - val_accuracy: 0.6981 - val_loss: 0.6688
# Epoch 25/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7242 - loss: 0.6183 - val_accuracy: 0.6936 - val_loss: 0.6914
# Epoch 26/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7194 - loss: 0.6272 - val_accuracy: 0.6951 - val_loss: 0.6913
# Epoch 27/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7245 - loss: 0.6368 - val_accuracy: 0.6981 - val_loss: 0.6810
# Epoch 28/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7408 - loss: 0.6276 - val_accuracy: 0.7010 - val_loss: 0.6778
# Epoch 29/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7276 - loss: 0.6247 - val_accuracy: 0.7010 - val_loss: 0.6815
# Epoch 30/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7235 - loss: 0.6287 - val_accuracy: 0.7100 - val_loss: 0.6659
# Epoch 31/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7376 - loss: 0.6188 - val_accuracy: 0.7070 - val_loss: 0.6730
# Epoch 32/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7224 - loss: 0.6175 - val_accuracy: 0.6921 - val_loss: 0.6728
# Epoch 33/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7444 - loss: 0.5954 - val_accuracy: 0.6981 - val_loss: 0.6800
# Epoch 34/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7411 - loss: 0.6041 - val_accuracy: 0.6861 - val_loss: 0.7080
# Epoch 35/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7290 - loss: 0.6145 - val_accuracy: 0.6981 - val_loss: 0.6794
# Epoch 36/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7267 - loss: 0.5971 - val_accuracy: 0.6996 - val_loss: 0.6705
# Epoch 37/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7235 - loss: 0.6314 - val_accuracy: 0.7055 - val_loss: 0.6750
# Epoch 38/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7330 - loss: 0.6072 - val_accuracy: 0.6996 - val_loss: 0.6838
# Epoch 39/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7435 - loss: 0.5988 - val_accuracy: 0.6921 - val_loss: 0.6704
# Epoch 40/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7295 - loss: 0.6068 - val_accuracy: 0.6861 - val_loss: 0.6704
# Epoch 41/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7318 - loss: 0.6215 - val_accuracy: 0.6996 - val_loss: 0.6814
# Epoch 42/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7311 - loss: 0.5942 - val_accuracy: 0.6816 - val_loss: 0.6824
# Epoch 43/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7244 - loss: 0.6158 - val_accuracy: 0.6936 - val_loss: 0.6861
# Epoch 44/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7425 - loss: 0.5983 - val_accuracy: 0.6966 - val_loss: 0.6679
# Epoch 45/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7452 - loss: 0.5833 - val_accuracy: 0.6981 - val_loss: 0.6714
# Epoch 46/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7490 - loss: 0.5782 - val_accuracy: 0.6876 - val_loss: 0.6780
# Epoch 47/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.
100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7453 - loss: 0.5672 - val_accuracy: 0.6801 - val_loss: 0.7043
# Epoch 76/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7524 - loss: 0.5610 - val_accuracy: 0.6861 - val_loss: 0.7122
# Epoch 77/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7461 - loss: 0.5940 - val_accuracy: 0.6846 - val_loss: 0.6912
# Epoch 78/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7497 - loss: 0.5648 - val_accuracy: 0.6951 - val_loss: 0.7087
# Epoch 79/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7456 - loss: 0.5667 - val_accuracy: 0.6906 - val_loss: 0.7108
# Epoch 80/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7281 - loss: 0.5950 - val_accuracy: 0.6816 - val_loss: 0.7190
# Epoch 81/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7709 - loss: 0.5404 - val_accuracy: 0.6831 - val_loss: 0.7306
# Epoch 82/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7606 - loss: 0.5608 - val_accuracy: 0.6786 - val_loss: 0.7044
# Epoch 83/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7462 - loss: 0.5618 - val_accuracy: 0.6876 - val_loss: 0.7157
# Epoch 84/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7526 - loss: 0.5619 - val_accuracy: 0.6801 - val_loss: 0.7093
# Epoch 85/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7589 - loss: 0.5567 - val_accuracy: 0.6801 - val_loss: 0.7202
# Epoch 86/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7638 - loss: 0.5587 - val_accuracy: 0.6801 - val_loss: 0.7104
# Epoch 87/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7709 - loss: 0.5532 - val_accuracy: 0.6936 - val_loss: 0.7209
# Epoch 88/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7553 - loss: 0.5690 - val_accuracy: 0.6921 - val_loss: 0.7298
# Epoch 89/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7345 - loss: 0.5993 - val_accuracy: 0.6786 - val_loss: 0.7332
# Epoch 90/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7513 - loss: 0.5687 - val_accuracy: 0.6741 - val_loss: 0.7258
# Epoch 91/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7430 - loss: 0.5729 - val_accuracy: 0.6831 - val_loss: 0.7189
# Epoch 92/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7544 - loss: 0.5297 - val_accuracy: 0.6741 - val_loss: 0.7169
# Epoch 93/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7492 - loss: 0.5758 - val_accuracy: 0.6906 - val_loss: 0.7181
# Epoch 94/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7657 - loss: 0.5488 - val_accuracy: 0.6846 - val_loss: 0.7264
# Epoch 95/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7743 - loss: 0.5331 - val_accuracy: 0.6831 - val_loss: 0.7296
# Epoch 96/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7506 - loss: 0.5501 - val_accuracy: 0.6726 - val_loss: 0.7124
# Epoch 97/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7647 - loss: 0.5620 - val_accuracy: 0.6622 - val_loss: 0.7147
# Epoch 98/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7549 - loss: 0.5497 - val_accuracy: 0.6756 - val_loss: 0.7061
# Epoch 99/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7572 - loss: 0.5571 - val_accuracy: 0.6726 - val_loss: 0.7214
# Epoch 100/100
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.7637 - loss: 0.5375 - val_accuracy: 0.6756 - val_loss: 0.7247

# %%
# 5. 모델 평가
loss, accuracy = model.evaluate(X_test, y_test)
print(f'\nTest accuracy: {accuracy:.4f}')
# Out:
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7032 - loss: 0.6530
#
# Test accuracy: 0.7081

# %%
# 6. 학습 과정 시각화
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 4))

# Accuracy 그래프
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# %%
# Loss 그래프
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# 7. 혼동 행렬 시각화
from sklearn.metrics import confusion_matrix
import seaborn as sns

y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_test_classes = np.argmax(y_test, axis=1)

cm = confusion_matrix(y_test_classes, y_pred_classes)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step
